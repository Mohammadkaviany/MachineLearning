# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammadkaviany/MachineLearning/blob/main/KMeans_with_SKlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Mohammadkaviany/MachineLearning.git

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning Tutorials/kmeans_blobs.csv")
df = df[['x', 'y']]

# %%
kmeans = KMeans(3)
model = kmeans.fit(df)
predict = model.predict(df)

# %%
centroids = model.cluster_centers_
centroids
# Out:
# array([[ 6.32286667, 19.5598    ],
#        [29.33086364, 10.43240909],
#        [29.30495652, 39.05078261]])

# %%
plt.figure(figsize=(15, 10))
plt.scatter(centroids[:, 0], centroids[:, 1], c= 'r')
plt.scatter(df.x, df.y, c=predict, s = 20 ,cmap='viridis')
